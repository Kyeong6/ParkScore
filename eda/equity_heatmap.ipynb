# %% [markdown]
# # Equity Visualization
#
# ParkScore에 사용되는 지표 중 공평의 시각화를 진행한다.
# 공평은 도시공원 배치의 "공간적 형평성"에 초점을 두어 점수화를 진행했다.
# 해당 시각화는 85개 도시 중 "광주광역시"을 예로 들어 진행했다.

# %% [markdown]
# ## Import
#
# - 공공데이터 포털 : [전국도시공원정보표준데이터](https://www.data.go.kr/data/15012890/standard.do) 사용

# %%
# !jupyter nbextension install --sys-prefix --symlink --overwrite --py pydeck
# !jupyter nbextension enable --sys-prefix --py pydeck
# Out:
# Installing /Users/kyeong6/anaconda3/lib/python3.11/site-packages/pydeck/nbextension/static -> pydeck
# Removing: /Users/kyeong6/anaconda3/share/jupyter/nbextensions/pydeck
# Symlinking: /Users/kyeong6/anaconda3/share/jupyter/nbextensions/pydeck -> /Users/kyeong6/anaconda3/lib/python3.11/site-packages/pydeck/nbextension/static
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable pydeck --py --sys-prefix
#
# Enabling notebook extension pydeck/extensionRequires...
#       - Validating: OK

# %%
import pandas as pd
import pydeck as pdk
import geopandas as gpd
from shapely import wkt
from shapely.geometry import MultiPolygon, Polygon, Point
import json

from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
try:
    df = pd.read_csv('/Users/kyeong6/Desktop/analysis/park/urban_park_data/urban_park.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        df = pd.read_csv('/Users/kyeong6/Desktop/analysis/park/urban_park_data/urban_park.csv', encoding='cp949')
    except Exception as e:
        print(f"Error: {e}")

# %%
df
# Out:
#               관리번호         공원명  공원구분            소재지도로명주소  \
# 0      41830-00017    광탄2호 소공원   소공원                 NaN
# 1      41830-00031    광탄3호 소공원   소공원                 NaN
# 2      41830-00018      공흥 소공원   소공원                 NaN
# 3      41830-00019   한강아트로드 공원   소공원                 NaN
# 4      41830-00020      강하 소공원   소공원  경기도 양평군 강하면 운심길 58
# ...            ...         ...   ...                 ...
# 18853  28110-00116  영종하늘도시 33호  근린공원                 NaN
# 18854  28110-00117  영종하늘도시 34호  근린공원                 NaN
# 18855  28110-00118  영종하늘도시 35호  근린공원                 NaN
# 18856  28110-00119  영종하늘도시 36호  근린공원                 NaN
# 18857  28110-00120  영종하늘도시 37호  근린공원                 NaN
#
#                      소재지지번주소         위도          경도     공원면적  공원보유시설(운동시설)  \
# 0        경기도 양평군 용문면 광탄리 711  37.509628  127.628406    856.0           NaN
# 1        경기도 양평군 용문면 광탄리 762  37.508443  127.627414    847.0           NaN
# 2      경기도 양평군 양평읍 공흥리 885-1  37.493844  127.509326   1276.0           NaN
# 3      경기도 양평군 강하면 운심리 43-25  37.496021  127.408216   3300.0           NaN
# 4       경기도 양평군 강하면 운심리 28-1  37.496164  127.412326    394.0  농구장+축구장+테니스장
# ...                      ...        ...         ...      ...           ...
# 18853    인천광역시 중구 중산동 1959-2  37.492194  126.575593   8652.0           NaN
# 18854   인천광역시 중구 운남동 1745-10  37.482082  126.540403  43514.0           NaN
# 18855    인천광역시 중구 운남동 1681-9  37.480161  126.509114  55128.0           NaN
# 18856   인천광역시 중구 중산동 1926-19  37.497137  126.575911  10172.0           NaN
# 18857   인천광역시 중구 운남동 1722-84  37.482703  126.516949  28384.0           NaN
#
#       공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설) 공원보유시설(기타시설)       지정고시일  \
# 0              NaN          NaN          NaN          NaN  1994-02-25
# 1              NaN          NaN          NaN          NaN  1994-02-25
# 2              NaN          NaN          NaN          NaN  2012-11-22
# 3              NaN          NaN          NaN          NaN  2012-08-30
# 4              NaN          NaN          NaN          NaN  2012-08-30
# ...            ...          ...          ...          ...         ...
# 18853          NaN          NaN          NaN          NaN         NaN
# 18854          NaN          NaN          NaN          NaN         NaN
# 18855          NaN          NaN          NaN          NaN         NaN
# 18856          NaN          NaN          NaN          NaN         NaN
# 18857          NaN          NaN          NaN          NaN         NaN
#
#            관리기관명          전화번호     데이터기준일자   제공기관코드     제공기관명
# 0       경기도 양평군청  031-770-2358  2023-05-26  4170000   경기도 양평군
# 1       경기도 양평군청  031-770-2358  2023-05-26  4170000   경기도 양평군
# 2       경기도 양평군청  031-770-2358  2023-05-26  4170000   경기도 양평군
# 3       경기도 양평군청  031-770-2358  2023-05-26  4170000   경기도 양평군
# 4       경기도 양평군청  031-770-2358  2023-05-26  4170000   경기도 양평군
# ...          ...           ...         ...      ...       ...
# 18853  인천광역시 중구청  032-760-7777  2023-05-16  3490000  인천광역시 중구
# 18854  인천광역시 중구청  032-760-7777  2023-05-16  3490000  인천광역시 중구
# 18855  인천광역시 중구청  032-760-7777  2023-05-16  3490000  인천광역시 중구
# 18856  인천광역시 중구청  032-760-7777  2023-05-16  3490000  인천광역시 중구
# 18857  인천광역시 중구청  032-760-7777  2023-05-16  3490000  인천광역시 중구
#
# [18858 rows x 19 columns]

# %% [markdown]
# ## Data Preprocessing
#
# - "제공기관명"에서 광주광역시가 포함된 단어를 찾아 광주광역시 데이터를 얻는다.

# %%
# "제공기관명" 열에서 "광주광역시"가 포함된 행 필터링
gwangju = df[df['제공기관명'].str.contains('광주광역시')]

# %%
gwangju
# Out:
#               관리번호      공원명   공원구분              소재지도로명주소  \
# 79     29200-00173       선운   근린공원  광주광역시 광산구 선운로2번길 2-1
# 80     29200-00174       우주  어린이공원                   NaN
# 81     29200-00175      무지개  어린이공원                   NaN
# 82     29200-00176       풍물  어린이공원                   NaN
# 83     29200-00177     신창제2  어린이공원                   NaN
# ...            ...      ...    ...                   ...
# 18546  29170-00006  지우어린이공원  어린이공원                   NaN
# 18547  29170-00007  신안어린이공원  어린이공원                   NaN
# 18548  29170-00008  효동어린이공원  어린이공원                   NaN
# 18549  29170-00009   우산근린공원   근린공원                   NaN
# 18550  29170-00010     천변공원   수변공원                   NaN
#
#                       소재지지번주소         위도          경도      공원면적 공원보유시설(운동시설)  \
# 79     광주광역시 광산구 선암동 544외 4필지  35.148105  126.769051   59093.5    농구장+배드민턴장
# 80          광주광역시 광산구 선암동 637  35.146419  126.775342    1509.1          NaN
# 81          광주광역시 광산구 선암동 542  35.146506  126.778525    1585.0          NaN
# 82          광주광역시 광산구 선암동 550  35.150287  126.776045    3388.5         운동공간
# 83        광주광역시 광산구 신창동 산92-2  35.190883  126.848145    2000.0          NaN
# ...                       ...        ...         ...       ...          ...
# 18546      광주광역시 북구 운암동 478-1  35.175488  126.884076    3860.5          NaN
# 18547      광주광역시 북구 신안동 471-1  35.171617  126.898298    3817.5          NaN
# 18548      광주광역시 북구 중흥동 347-1  35.168287  126.909239    4205.0          NaN
# 18549      광주광역시 북구 우산동 228-1  35.175626  126.926242  133120.0          NaN
# 18550       광주광역시 북구 임동 226-9  35.160485  126.894084  424420.0          NaN
#
#             공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설) 공원보유시설(기타시설)       지정고시일  \
# 79                   NaN          화장실          NaN  관리사무소+노인복지관  2006-05-29
# 80               시소+조합놀이          NaN          NaN          NaN  2006-05-29
# 81               그네+조합놀이          NaN          NaN          NaN  2006-05-29
# 82     그네+시소+조합놀이+기타놀이기구          NaN          NaN          NaN  2006-05-29
# 83                   NaN          NaN          NaN          NaN  2006-05-29
# ...                  ...          ...          ...          ...         ...
# 18546                NaN          NaN          NaN          NaN  1970-06-05
# 18547                NaN          NaN          NaN          NaN  1970-06-05
# 18548                NaN          NaN          NaN          NaN  1970-06-05
# 18549                NaN          NaN          NaN          NaN  1975-02-18
# 18550                NaN          NaN          NaN          NaN  1975-02-18
#
#             관리기관명          전화번호     데이터기준일자   제공기관코드      제공기관명
# 79     광주광역시 광산구청  062-960-8713  2023-03-16  3630000  광주광역시 광산구
# 80     광주광역시 광산구청  062-960-8689  2023-03-16  3630000  광주광역시 광산구
# 81     광주광역시 광산구청  062-960-8689  2023-03-16  3630000  광주광역시 광산구
# 82     광주광역시 광산구청  062-960-8689  2023-03-16  3630000  광주광역시 광산구
# 83     광주광역시 광산구청  062-960-8689  2023-03-16  3630000  광주광역시 광산구
# ...           ...           ...         ...      ...        ...
# 18546   광주광역시 북구청  062-410-6441  2024-01-31  3620000   광주광역시 북구
# 18547   광주광역시 북구청  062-410-6441  2024-01-31  3620000   광주광역시 북구
# 18548   광주광역시 북구청  062-410-6441  2024-01-31  3620000   광주광역시 북구
# 18549   광주광역시 북구청  062-410-6441  2024-01-31  3620000   광주광역시 북구
# 18550   광주광역시 북구청  062-410-6441  2024-01-31  3620000   광주광역시 북구
#
# [530 rows x 19 columns]

# %%
gwangju.columns
# Out:
# Index(['관리번호', '공원명', '공원구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '공원면적',
#        '공원보유시설(운동시설)', '공원보유시설(유희시설)', '공원보유시설(편익시설)', '공원보유시설(교양시설)',
#        '공원보유시설(기타시설)', '지정고시일', '관리기관명', '전화번호', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
# 필요한 열만 사용
gwangju = gwangju[['공원명', '공원구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '공원면적', '제공기관명']]
gwangju = gwangju.reset_index().drop(['index'], axis=1)

# %%
gwangju
# Out:
#          공원명   공원구분              소재지도로명주소                 소재지지번주소         위도  \
# 0         선운   근린공원  광주광역시 광산구 선운로2번길 2-1  광주광역시 광산구 선암동 544외 4필지  35.148105
# 1         우주  어린이공원                   NaN       광주광역시 광산구 선암동 637  35.146419
# 2        무지개  어린이공원                   NaN       광주광역시 광산구 선암동 542  35.146506
# 3         풍물  어린이공원                   NaN       광주광역시 광산구 선암동 550  35.150287
# 4       신창제2  어린이공원                   NaN     광주광역시 광산구 신창동 산92-2  35.190883
# ..       ...    ...                   ...                     ...        ...
# 525  지우어린이공원  어린이공원                   NaN      광주광역시 북구 운암동 478-1  35.175488
# 526  신안어린이공원  어린이공원                   NaN      광주광역시 북구 신안동 471-1  35.171617
# 527  효동어린이공원  어린이공원                   NaN      광주광역시 북구 중흥동 347-1  35.168287
# 528   우산근린공원   근린공원                   NaN      광주광역시 북구 우산동 228-1  35.175626
# 529     천변공원   수변공원                   NaN       광주광역시 북구 임동 226-9  35.160485
#
#              경도      공원면적      제공기관명
# 0    126.769051   59093.5  광주광역시 광산구
# 1    126.775342    1509.1  광주광역시 광산구
# 2    126.778525    1585.0  광주광역시 광산구
# 3    126.776045    3388.5  광주광역시 광산구
# 4    126.848145    2000.0  광주광역시 광산구
# ..          ...       ...        ...
# 525  126.884076    3860.5   광주광역시 북구
# 526  126.898298    3817.5   광주광역시 북구
# 527  126.909239    4205.0   광주광역시 북구
# 528  126.926242  133120.0   광주광역시 북구
# 529  126.894084  424420.0   광주광역시 북구
#
# [530 rows x 8 columns]

# %% [markdown]
# ### 결측치 해결
#
# - 현재 소재지지번주소가 많은 값을 가지지만, 소재지지번주소가 NaN값이고 소재지도로명주소 값이 존재하는 경우가 있어 수작업으로 결측치 해결

# %%
# gwangju.to_csv('./gwangju.csv', encoding='cp949')

# %%
try:
    gwangju = pd.read_csv('./gwangju.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        gwangju = pd.read_csv('./gwangju.csv', encoding='cp949')
    except Exception as e:
        print(f"Error: {e}")

# %%
gwangju
# Out:
#      Unnamed: 0                 소재지지번주소   latitude   longitude  urban_park
# 0             0  광주광역시 광산구 선암동 544외 4필지  35.148105  126.769051     59093.5
# 1             1       광주광역시 광산구 선암동 637  35.146419  126.775342      1509.1
# 2             2       광주광역시 광산구 선암동 542  35.146506  126.778525      1585.0
# 3             3       광주광역시 광산구 선암동 550  35.150287  126.776045      3388.5
# 4             4     광주광역시 광산구 신창동 산92-2  35.190883  126.848145      2000.0
# ..          ...                     ...        ...         ...         ...
# 525         525      광주광역시 북구 운암동 478-1  35.175488  126.884076      3860.5
# 526         526      광주광역시 북구 신안동 471-1  35.171617  126.898298      3817.5
# 527         527      광주광역시 북구 중흥동 347-1  35.168287  126.909239      4205.0
# 528         528      광주광역시 북구 우산동 228-1  35.175626  126.926242    133120.0
# 529         529       광주광역시 북구 임동 226-9  35.160485  126.894084    424420.0
#
# [530 rows x 5 columns]

# %%
# # 필요하지 않은 열 제거
# gwangju = gwangju.drop(['공원명', '공원구분', '소재지도로명주소', '제공기관명'], axis=1)

# %% [markdown]
# ### Geojson
#
# - 광주광역시 행정구역(동) Geojson 사용
# - 해당 데이터는 qgis를 통해 shp 파일을 Geojson으로 변환

# %%
# geojson 업로드
geojson_file = './gwangju.geojson'
gwangju_gdf = gpd.read_file(geojson_file)

# %%
gwangju_gdf
# Out:
#        EMD_CD           EMD_ENG_NM EMD_KOR_NM  \
# 0    29110101           Daein-dong        대인동
# 1    29110102    Geumnamno 5(o)-ga      금남로5가
# 2    29110103  Chungjangno 5(o)-ga      충장로5가
# 3    29110104            Sugi-dong        수기동
# 4    29110105           Daeui-dong        대의동
# ..        ...                  ...        ...
# 196  29200175          Dongho-dong        동호동
# 197  29200176        Deongnim-dong        덕림동
# 198  29200177         Yangsan-dong        양산동
# 199  29200178         Dongnim-dong        동림동
# 200  29200202           Oseon-dong        오선동
#
#                                               geometry
# 0    MULTIPOLYGON (((946602.933 1684771.874, 946606...
# 1    MULTIPOLYGON (((946379.695 1684546.386, 946394...
# 2    MULTIPOLYGON (((946229.498 1684396.631, 946229...
# 3    MULTIPOLYGON (((946147.252 1684316.603, 946151...
# 4    MULTIPOLYGON (((947208.394 1684087.413, 947208...
# ..                                                 ...
# 196  MULTIPOLYGON (((925390.284 1689048.240, 925421...
# 197  MULTIPOLYGON (((924553.149 1689031.013, 924576...
# 198  MULTIPOLYGON (((926147.201 1689014.876, 926144...
# 199  MULTIPOLYGON (((926413.305 1691165.365, 926415...
# 200  MULTIPOLYGON (((935001.339 1689433.358, 935002...
#
# [201 rows x 4 columns]

# %%
# gwangju_gdf.to_csv('gwangju_gdf.csv', encoding='cp949')

# %% [markdown]
# ### 데이터셋 변경
#
# - 기존에 광주광역시 행정구역(동) Geojson 사용하였지만, 도시공원의 위도/경도가 존재하여 데이터셋을 변경
# - pydeck 코드에 적용하기 위해 열이름 변경 필요

# %%
gwangju
# Out:
#      Unnamed: 0                 소재지지번주소   latitude   longitude  urban_park
# 0             0  광주광역시 광산구 선암동 544외 4필지  35.148105  126.769051     59093.5
# 1             1       광주광역시 광산구 선암동 637  35.146419  126.775342      1509.1
# 2             2       광주광역시 광산구 선암동 542  35.146506  126.778525      1585.0
# 3             3       광주광역시 광산구 선암동 550  35.150287  126.776045      3388.5
# 4             4     광주광역시 광산구 신창동 산92-2  35.190883  126.848145      2000.0
# ..          ...                     ...        ...         ...         ...
# 525         525      광주광역시 북구 운암동 478-1  35.175488  126.884076      3860.5
# 526         526      광주광역시 북구 신안동 471-1  35.171617  126.898298      3817.5
# 527         527      광주광역시 북구 중흥동 347-1  35.168287  126.909239      4205.0
# 528         528      광주광역시 북구 우산동 228-1  35.175626  126.926242    133120.0
# 529         529       광주광역시 북구 임동 226-9  35.160485  126.894084    424420.0
#
# [530 rows x 5 columns]

# %%
# 열 이름 변경
gwangju.rename(columns={
    '위도' : 'latitude',
    '경도' : 'longitude',
    '공원면적' : 'urban_park'
}, inplace=True)

# %%
gwangju
# Out:
#      Unnamed: 0                 소재지지번주소   latitude   longitude  urban_park
# 0             0  광주광역시 광산구 선암동 544외 4필지  35.148105  126.769051     59093.5
# 1             1       광주광역시 광산구 선암동 637  35.146419  126.775342      1509.1
# 2             2       광주광역시 광산구 선암동 542  35.146506  126.778525      1585.0
# 3             3       광주광역시 광산구 선암동 550  35.150287  126.776045      3388.5
# 4             4     광주광역시 광산구 신창동 산92-2  35.190883  126.848145      2000.0
# ..          ...                     ...        ...         ...         ...
# 525         525      광주광역시 북구 운암동 478-1  35.175488  126.884076      3860.5
# 526         526      광주광역시 북구 신안동 471-1  35.171617  126.898298      3817.5
# 527         527      광주광역시 북구 중흥동 347-1  35.168287  126.909239      4205.0
# 528         528      광주광역시 북구 우산동 228-1  35.175626  126.926242    133120.0
# 529         529       광주광역시 북구 임동 226-9  35.160485  126.894084    424420.0
#
# [530 rows x 5 columns]

# %%
# gwangju.to_csv('/Users/kyeong6/desktop/gwangju.csv', encoding='cp949')

# %% [markdown]
# ## Heatmap
#
# - gwangju_gdf.csv 파일에 "urban_park" 열을 생성하고, 도시공원 면적 값을 넣은 뒤 업로드

# %%
# Mapbox api token 설정
MAP_BOX_API = os.getenv('MAPBOX_API_KEY')
pdk.settings.mapbox_api_key = MAP_BOX_API

# %%
try:
    gwangju_gdf = pd.read_csv('./gwangju_gdf.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        gwangju_gdf = pd.read_csv('./gwangju_gdf.csv', encoding='cp949')
    except Exception as e:
        print(f"Error: {e}")

# %%
gwangju_gdf
# Out:
#        EMD_CD           EMD_ENG_NM EMD_KOR_NM  urban_park  \
# 0    29110101           Daein-dong        대인동    424420.0
# 1    29110102    Geumnamno 5(o)-ga      금남로5가    424420.0
# 2    29110103  Chungjangno 5(o)-ga      충장로5가    424420.0
# 3    29110104            Sugi-dong        수기동    424420.0
# 4    29110105           Daeui-dong        대의동    424420.0
# ..        ...                  ...        ...         ...
# 196  29200175          Dongho-dong        동호동     53012.9
# 197  29200176        Deongnim-dong        덕림동     53012.9
# 198  29200177         Yangsan-dong        양산동     39684.0
# 199  29200178         Dongnim-dong        동림동    379395.9
# 200  29200202           Oseon-dong        오선동    714329.6
#
#                                               geometry
# 0    MULTIPOLYGON (((946602.933195839 1684771.87406...
# 1    MULTIPOLYGON (((946379.6951006013 1684546.3860...
# 2    MULTIPOLYGON (((946229.4983861081 1684396.6305...
# 3    MULTIPOLYGON (((946147.2517786798 1684316.6025...
# 4    MULTIPOLYGON (((947208.3938648928 1684087.4134...
# ..                                                 ...
# 196  MULTIPOLYGON (((925390.2842348986 1689048.2395...
# 197  MULTIPOLYGON (((924553.1492866804 1689031.0126...
# 198  MULTIPOLYGON (((926147.2005513686 1689014.8759...
# 199  MULTIPOLYGON (((926413.3045293004 1691165.3646...
# 200  MULTIPOLYGON (((935001.3393339419 1689433.3581...
#
# [201 rows x 5 columns]

# %%
# geometry 열을 shapely 객체로 변환
gwangju_gdf['geometry'] = gwangju_gdf['geometry'].apply(wkt.loads)

# %%
# # 폴리곤 및 멀티폴리곤 좌표 추출 함수 정의
# def polygon_to_coordinates(geom):
#     if isinstance(geom, Polygon):
#         lon, lat = geom.exterior.xy
#         return [[x, y] for x, y in zip(lon, lat)]
#     elif isinstance(geom, MultiPolygon):
#         coords = []
#         for poly in geom.geoms:
#             lon, lat = poly.exterior.xy
#             coords.append([[x, y] for x, y in zip(lon, lat)])
#         return coords
#     else:
#         return []

# %%
# # 좌표 변환 함수 적용
# gwangju_gdf['coordinates'] = gwangju_gdf['geometry'].apply(polygon_to_coordinates)

# %%
gwangju_gdf
# Out:
#        EMD_CD           EMD_ENG_NM EMD_KOR_NM  urban_park  \
# 0    29110101           Daein-dong        대인동    424420.0
# 1    29110102    Geumnamno 5(o)-ga      금남로5가    424420.0
# 2    29110103  Chungjangno 5(o)-ga      충장로5가    424420.0
# 3    29110104            Sugi-dong        수기동    424420.0
# 4    29110105           Daeui-dong        대의동    424420.0
# ..        ...                  ...        ...         ...
# 196  29200175          Dongho-dong        동호동     53012.9
# 197  29200176        Deongnim-dong        덕림동     53012.9
# 198  29200177         Yangsan-dong        양산동     39684.0
# 199  29200178         Dongnim-dong        동림동    379395.9
# 200  29200202           Oseon-dong        오선동    714329.6
#
#                                               geometry
# 0    MULTIPOLYGON (((946602.933195839 1684771.87406...
# 1    MULTIPOLYGON (((946379.6951006013 1684546.3860...
# 2    MULTIPOLYGON (((946229.4983861081 1684396.6305...
# 3    MULTIPOLYGON (((946147.2517786798 1684316.6025...
# 4    MULTIPOLYGON (((947208.3938648928 1684087.4134...
# ..                                                 ...
# 196  MULTIPOLYGON (((925390.2842348986 1689048.2395...
# 197  MULTIPOLYGON (((924553.1492866804 1689031.0126...
# 198  MULTIPOLYGON (((926147.2005513686 1689014.8759...
# 199  MULTIPOLYGON (((926413.3045293004 1691165.3646...
# 200  MULTIPOLYGON (((935001.3393339419 1689433.3581...
#
# [201 rows x 5 columns]

# %%
gwangju_gdf['geometry'].dtype
# Out:
# dtype('O')

# %%
# GeoDataFrame 생성
gwangju_gdf = gpd.GeoDataFrame(gwangju_gdf, geometry='geometry')

# 현재 좌표계를 설정
gwangju_gdf.crs = "EPSG:5179"

# 좌표계 WGS84로 변환
gwangju_gdf = gwangju_gdf.to_crs(epsg=4326)

# %%
# 중심 좌표 계산 함수
def calculate_centroid(geometry):
    if isinstance(geometry, MultiPolygon):
        centroid = geometry.centroid
    elif isinstance(geometry, Polygon):
        centroid = geometry.centroid
    return centroid.y, centroid.x

# %%
# 중심 좌표 구하기(위도 / 경도)
gwangju_gdf['latitude'], gwangju_gdf['longitude'] = zip(*gwangju_gdf['geometry'].apply(calculate_centroid))

# %%
gwangju_gdf['latitude'].dtype
# Out:
# dtype('float64')

# %%
#  필요한 열만 선택
gwangju_gdf = gwangju_gdf[['EMD_KOR_NM', 'urban_park', 'latitude', 'longitude']]

# %%
# null 값 확인
print(gwangju_gdf.isnull().sum())
# Out:
# EMD_KOR_NM    0
# urban_park    0
# latitude      0
# longitude     0
# dtype: int64

# %%
gwangju_gdf
# Out:
#     EMD_KOR_NM  urban_park   latitude   longitude
# 0          대인동    424420.0  35.154010  126.915223
# 1        금남로5가    424420.0  35.152697  126.912337
# 2        충장로5가    424420.0  35.151344  126.911238
# 3          수기동    424420.0  35.150502  126.909713
# 4          대의동    424420.0  35.149117  126.920520
# ..         ...         ...        ...         ...
# 196        동호동     53012.9  35.182639  126.687332
# 197        덕림동     53012.9  35.183131  126.670041
# 198        양산동     39684.0  35.197487  126.688780
# 199        동림동    379395.9  35.206535  126.691207
# 200        오선동    714329.6  35.202691  126.799852
#
# [201 rows x 4 columns]

# %%
# HeatmapLayer 생성
layer = pdk.Layer(
    'HeatmapLayer',
    data=gwangju_gdf,
    get_position='[longitude, latitude]',
    get_weight='urban_park',
    radiusPixels=50,
)

# pydeck View 생성
view_state = pdk.ViewState(
    longitude=gwangju_gdf['longitude'].mean(),
    latitude=gwangju_gdf['latitude'].mean(),
    zoom=12
)

# pydeck Deck 생성
deck = pdk.Deck(
    layers=[layer],
    initial_view_state=view_state,
#     map_style='mapbox://styles/mapbox/light-v10',  # Mapbox 스타일 설정
    tooltip={"text": "동: {EMD_KOR_NM}\n도시공원 면적: {urban_park} sqm"}
)

# %%
# pydeck 저장 및 표시
output_path = './equity_html/equity_heatmap.html'
deck.to_html(output_path)

deck.show()
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~9.0.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 35.15504013112308,
#     &quot;longitude&quot;: 126.84232784741138,
#     &quot;zoom&quot;: 12
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;HeatmapLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ub300\uc778\ub3d9&quot;,
#           &quot;latitude&quot;: 35.15401035380854,
#           &quot;longitude&quot;: 126.91522346353547,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uae08\ub0a8\ub85c5\uac00&quot;,
#           &quot;latitude&quot;: 35.15269682873973,
#           &quot;longitude&quot;: 126.91233743697798,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ucda9\uc7a5\ub85c5\uac00&quot;,
#           &quot;latitude&quot;: 35.15134421458695,
#           &quot;longitude&quot;: 126.91123821980457,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc218\uae30\ub3d9&quot;,
#           &quot;latitude&quot;: 35.15050241309521,
#           &quot;longitude&quot;: 126.9097126136924,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ub300\uc758\ub3d9&quot;,
#           &quot;latitude&quot;: 35.14911662649427,
#           &quot;longitude&quot;: 126.92052039445113,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uad81\ub3d9&quot;,
#           &quot;latitude&quot;: 35.15060376445042,
#           &quot;longitude&quot;: 126.9183885449769,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc7a5\ub3d9&quot;,
#           &quot;latitude&quot;: 35.15007253684979,
#           &quot;longitude&quot;: 126.92179125725184,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ub3d9\uba85\ub3d9&quot;,
#           &quot;latitude&quot;: 35.15056785596423,
#           &quot;longitude&quot;: 126.92543761649445,
#           &quot;urban_park&quot;: 276296.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uacc4\ub9bc\ub3d9&quot;,
#           &quot;latitude&quot;: 35.15975545564276,
#           &quot;longitude&quot;: 126.92053830715774,
#           &quot;urban_park&quot;: 141576.1
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc0b0\uc218\ub3d9&quot;,
#           &quot;latitude&quot;: 35.156505534001994,
#           &quot;longitude&quot;: 126.93414045585659,
#           &quot;urban_park&quot;: 46707.6
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc9c0\uc0b0\ub3d9&quot;,
#           &quot;latitude&quot;: 35.14860404591306,
#           &quot;longitude&quot;: 126.94227032176516,
#           &quot;urban_park&quot;: 215279.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ub0a8\ub3d9&quot;,
#           &quot;latitude&quot;: 35.14419685376706,
#           &quot;longitude&quot;: 126.92010519841632,
#           &quot;urban_park&quot;: 1976.9
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uad11\uc0b0\ub3d9&quot;,
#           &quot;latitude&quot;: 35.14649383825102,
#           &quot;longitude&quot;: 126.91947820423569,
#           &quot;urban_park&quot;: 1976.9
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uae08\ub3d9&quot;,
#           &quot;latitude&quot;: 35.14331172652883,
#           &quot;longitude&quot;: 126.91767704362604,
#           &quot;urban_park&quot;: 1976.9
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ud638\ub0a8\ub3d9&quot;,
#           &quot;latitude&quot;: 35.147615429344974,
#           &quot;longitude&quot;: 126.91249448126737,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ubd88\ub85c\ub3d9&quot;,
#           &quot;latitude&quot;: 35.14548503169253,
#           &quot;longitude&quot;: 126.91483050661843,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ud669\uae08\ub3d9&quot;,
#           &quot;latitude&quot;: 35.14730525569975,
#           &quot;longitude&quot;: 126.9155578780857,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc11c\uc11d\ub3d9&quot;,
#           &quot;latitude&quot;: 35.142167667942466,
#           &quot;longitude&quot;: 126.9296826796379,
#           &quot;urban_park&quot;: 1976.9
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc18c\ud0dc\ub3d9&quot;,
#           &quot;latitude&quot;: 35.11740299118881,
#           &quot;longitude&quot;: 126.94553630806917,
#           &quot;urban_park&quot;: 46862.2
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc6a9\uc5f0\ub3d9&quot;,
#           &quot;latitude&quot;: 35.10503807902549,
#           &quot;longitude&quot;: 126.97799791768735,
#           &quot;urban_park&quot;: 5713.8
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc6b4\ub9bc\ub3d9&quot;,
#           &quot;latitude&quot;: 35.12781469852202,
#           &quot;longitude&quot;: 126.96577151086983,
#           &quot;urban_park&quot;: 5713.8
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ud559\ub3d9&quot;,
#           &quot;latitude&quot;: 35.13666134831789,
#           &quot;longitude&quot;: 126.93150888316842,
#           &quot;urban_park&quot;: 156190.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc6d4\ub0a8\ub3d9&quot;,
#           &quot;latitude&quot;: 35.10249815071254,
#           &quot;longitude&quot;: 126.94080916702208,
#           &quot;urban_park&quot;: 46862.2
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc120\uad50\ub3d9&quot;,
#           &quot;latitude&quot;: 35.085332164463956,
#           &quot;longitude&quot;: 126.95188348689815,
#           &quot;urban_park&quot;: 46862.2
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ub0b4\ub0a8\ub3d9&quot;,
#           &quot;latitude&quot;: 35.08797367932537,
#           &quot;longitude&quot;: 126.93477147029421,
#           &quot;urban_park&quot;: 46862.2
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\uc6a9\uc0b0\ub3d9&quot;,
#           &quot;latitude&quot;: 35.11324748235101,
#           &quot;longitude&quot;: 126.92429261232947,
#           &quot;urban_park&quot;: 46862.2
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ucda9\uc7a5\ub85c1\uac00&quot;,
#           &quot;latitude&quot;: 35.1471247009984,
#           &quot;longitude&quot;: 126.91780829102329,
#           &quot;urban_park&quot;: 424420.0
#         },
#         {
#           &quot;EMD_KOR_NM&quot;: &quot;\ucda9\uc7a5\ub85c2\uac00&quot;,
#           &quot;latitude&quot;: 35.14802986016133,
#           &quot;longitude&quot;: 126.916504875456

# %% [markdown]
# ## 데이터셋 변경 후 Heatmap
#
# - 기존 데이터셋으로는 heatmap의 범위가 제대로 파악되지 않아 도시공원 위도 / 경도를 이용한 heatmap 확인
# - heatmap에서의 도시의 경계가 명확하지 않아 Polygon layer를 추가

# %%
# Mapbox api token 설정
MAP_BOX_API = os.getenv('MAPBOX_API_KEY')
pdk.settings.mapbox_api_key = MAP_BOX_API

# %%
try:
    gwangju = pd.read_csv('./gwangju.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        gwangju = pd.read_csv('./gwangju.csv', encoding='cp949')
    except Exception as e:
        print(f"Error: {e}")

# %%
gwangju = gwangju.drop(['Unnamed: 0'], axis=1)

# %%
gwangju
# Out:
#                     소재지지번주소   latitude   longitude  urban_park
# 0    광주광역시 광산구 선암동 544외 4필지  35.148105  126.769051     59093.5
# 1         광주광역시 광산구 선암동 637  35.146419  126.775342      1509.1
# 2         광주광역시 광산구 선암동 542  35.146506  126.778525      1585.0
# 3         광주광역시 광산구 선암동 550  35.150287  126.776045      3388.5
# 4       광주광역시 광산구 신창동 산92-2  35.190883  126.848145      2000.0
# ..                      ...        ...         ...         ...
# 525      광주광역시 북구 운암동 478-1  35.175488  126.884076      3860.5
# 526      광주광역시 북구 신안동 471-1  35.171617  126.898298      3817.5
# 527      광주광역시 북구 중흥동 347-1  35.168287  126.909239      4205.0
# 528      광주광역시 북구 우산동 228-1  35.175626  126.926242    133120.0
# 529       광주광역시 북구 임동 226-9  35.160485  126.894084    424420.0
#
# [530 rows x 4 columns]

# %%
# 필요한 열만 선택
gwangju = gwangju[['urban_park', 'latitude', 'longitude']]

# %%
# null 값 확인
print(gwangju.isnull().sum())
# Out:
# urban_park    0
# latitude      0
# longitude     0
# dtype: int64

# %%
gwangju
# Out:
#      urban_park   latitude   longitude
# 0       59093.5  35.148105  126.769051
# 1        1509.1  35.146419  126.775342
# 2        1585.0  35.146506  126.778525
# 3        3388.5  35.150287  126.776045
# 4        2000.0  35.190883  126.848145
# ..          ...        ...         ...
# 525      3860.5  35.175488  126.884076
# 526      3817.5  35.171617  126.898298
# 527      4205.0  35.168287  126.909239
# 528    133120.0  35.175626  126.926242
# 529    424420.0  35.160485  126.894084
#
# [530 rows x 3 columns]

# %%
# HeatmapLayer 생성
heatmap_layer = pdk.Layer(
    'HeatmapLayer',
    data=gwangju,
    get_position='[longitude, latitude]',
    get_weight='urban_park',
    radiusPixels=50,
)

# %%
# pydeck View 생성
view_state = pdk.ViewState(
    longitude=gwangju['longitude'].mean(),
    latitude=gwangju['latitude'].mean(),
    zoom=12
)

# %%
# pydeck Deck을 생성
deck = pdk.Deck(
    layers=heatmap_layer,
    initial_view_state=view_state,
#     map_style='mapbox://styles/mapbox/light-v10'
    tooltip={"text": "도시공원 면적: {urban_park} sqm"}
)

# %%
# pydeck 저장 및 표시
output_path = './equity_html/equity_heatmap2.html'
deck.to_html(output_path)

deck.show()
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~9.0.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 35.16463656369811,
#     &quot;longitude&quot;: 126.85325565452831,
#     &quot;zoom&quot;: 12
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;HeatmapLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;latitude&quot;: 35.14810487,
#           &quot;longitude&quot;: 126.7690505,
#           &quot;urban_park&quot;: 59093.5
#         },
#         {
#           &quot;latitude&quot;: 35.14641907,
#           &quot;longitude&quot;: 126.7753424,
#           &quot;urban_park&quot;: 1509.1
#         },
#         {
#           &quot;latitude&quot;: 35.14650606,
#           &quot;longitude&quot;: 126.7785246,
#           &quot;urban_park&quot;: 1585.0
#         },
#         {
#           &quot;latitude&quot;: 35.15028721,
#           &quot;longitude&quot;: 126.7760451,
#           &quot;urban_park&quot;: 3388.5
#         },
#         {
#           &quot;latitude&quot;: 35.19088265,
#           &quot;longitude&quot;: 126.8481452,
#           &quot;urban_park&quot;: 2000.0
#         },
#         {
#           &quot;latitude&quot;: 35.14877419,
#           &quot;longitude&quot;: 126.7718951,
#           &quot;urban_park&quot;: 810.8
#         },
#         {
#           &quot;latitude&quot;: 35.16429742,
#           &quot;longitude&quot;: 126.7372951,
#           &quot;urban_park&quot;: 597960.0
#         },
#         {
#           &quot;latitude&quot;: 35.16651629,
#           &quot;longitude&quot;: 126.6760589,
#           &quot;urban_park&quot;: 21629.0
#         },
#         {
#           &quot;latitude&quot;: 35.18336879,
#           &quot;longitude&quot;: 126.8026331,
#           &quot;urban_park&quot;: 14733.1
#         },
#         {
#           &quot;latitude&quot;: 35.16872986,
#           &quot;longitude&quot;: 126.7965787,
#           &quot;urban_park&quot;: 1523.0
#         },
#         {
#           &quot;latitude&quot;: 35.16945297,
#           &quot;longitude&quot;: 126.7969246,
#           &quot;urban_park&quot;: 1500.0
#         },
#         {
#           &quot;latitude&quot;: 35.18872107,
#           &quot;longitude&quot;: 126.8408106,
#           &quot;urban_park&quot;: 344.0
#         },
#         {
#           &quot;latitude&quot;: 35.15224353,
#           &quot;longitude&quot;: 126.8120006,
#           &quot;urban_park&quot;: 4982.0
#         },
#         {
#           &quot;latitude&quot;: 35.15992228,
#           &quot;longitude&quot;: 126.8075159,
#           &quot;urban_park&quot;: 1153.9
#         },
#         {
#           &quot;latitude&quot;: 35.20042404,
#           &quot;longitude&quot;: 126.825239,
#           &quot;urban_park&quot;: 11973.9
#         },
#         {
#           &quot;latitude&quot;: 35.21012185,
#           &quot;longitude&quot;: 126.7849692,
#           &quot;urban_park&quot;: 11316.0
#         },
#         {
#           &quot;latitude&quot;: 35.20617663,
#           &quot;longitude&quot;: 126.7827418,
#           &quot;urban_park&quot;: 34396.4
#         },
#         {
#           &quot;latitude&quot;: 35.20165986,
#           &quot;longitude&quot;: 126.7865874,
#           &quot;urban_park&quot;: 10089.8
#         },
#         {
#           &quot;latitude&quot;: 35.19860302,
#           &quot;longitude&quot;: 126.7934521,
#           &quot;urban_park&quot;: 34030.2
#         },
#         {
#           &quot;latitude&quot;: 35.19467039,
#           &quot;longitude&quot;: 126.7925899,
#           &quot;urban_park&quot;: 8445.7
#         },
#         {
#           &quot;latitude&quot;: 35.19304272,
#           &quot;longitude&quot;: 126.7901274,
#           &quot;urban_park&quot;: 10325.6
#         },
#         {
#           &quot;latitude&quot;: 35.20095796,
#           &quot;longitude&quot;: 126.7913344,
#           &quot;urban_park&quot;: 2492.9
#         },
#         {
#           &quot;latitude&quot;: 35.13059212,
#           &quot;longitude&quot;: 126.7512693,
#           &quot;urban_park&quot;: 13035.0
#         },
#         {
#           &quot;latitude&quot;: 35.18324459,
#           &quot;longitude&quot;: 126.8081936,
#           &quot;urban_park&quot;: 31737.0
#         },
#         {
#           &quot;latitude&quot;: 35.17584189,
#           &quot;longitude&quot;: 126.8234556,
#           &quot;urban_park&quot;: 1217.0
#         },
#         {
#           &quot;latitude&quot;: 35.17527441,
#           &quot;longitude&quot;: 126.8246387,
#           &quot;urban_park&quot;: 1846.0
#         },
#         {
#           &quot;latitude&quot;: 35.17364907,
#           &quot;longitude&quot;: 126.8230164,
#           &quot;urban_park&quot;: 1013.0
#         },
#         {
#           &quot;latitude&quot;: 35.17302431,
#           &quot;longitude&quot;: 126.8225052,
#           &quot;urban_park&quot;: 141.0
#         },
#         {
#           &quot;latitude&quot;: 35.19390912,
#           &quot;longitude&quot;: 126.8167391,
#           &quot;urban_park&quot;: 5999.5
#         },
#         {
#           &quot;latitude&quot;: 35.18990148,
#           &quot;longitude&quot;: 126.8117162,
#           &quot;urban_park&quot;: 1500.1
#         },
#         {
#           &quot;latitude&quot;: 35.18612707,
#           &quot;longitude&quot;: 126.8122464,
#           &quot;urban_park&quot;: 1554.3
#         },
#         {
#           &quot;latitude&quot;: 35.1938398,
#           &quot;longitude&quot;: 126.8183493,
#           &quot;urban_park&quot;: 2110.4
#         },
#         {
#           &quot;latitude&quot;: 35.18318112,
#           &quot;longitude&quot;: 126.8130803,
#           &quot;urban_park&quot;: 1605.6
#         },
#         {
#           &quot;latitude&quot;: 35.18122444,
#           &quot;longitude&quot;: 126.8104037,
#           &quot;urban_park&quot;: 1568.4
#         },
#         {
#           &quot;latitude&quot;: 35.18184585,
#           &quot;longitude&quot;: 126.8167373,
#           &quot;urban_park&quot;: 1500.7
#         },
#         {
#           &quot;latitude&quot;: 35.20113262,
#           &quot;longitude&quot;: 126.8222176,
#           &quot;urban_park&quot;: 1500.0
#         },
#         {
#           &quot;latitude&quot;: 35.20042404,
#           &quot;longitude&quot;: 126.825239,
#           &quot;urban_park&quot;: 1500.1
#         },
#         {
#           &quot;latitude&quot;: 35.1927626,
#           &quot;longitude&quot;: 126.8247774,
#           &quot;urban_park&quot;: 1500.0
#         },
#         {
#           &quot;latitude&quot;: 35.19282965,
#           &quot;longitude&quot;: 126.8311148,
#           &quot;urban_park&quot;: 2151.9
#         },
#         {
#           &quot;latitude&quot;: 35.18941133,
#           &quot;longitude&quot;: 126.8310335,
#           &quot;urban_park&quot;: 1500.0
#         },
#         {
#           &quot;latitude&quot;: 35.18868435,
#           &quot;longitude&quot;: 126.8302329,
#           &quot;urban_park&quot;: 1553.4
#         },
#         {
#           &quot;latitude&quot;: 35.18789158,
#           &quot;longitude&quot;: 126.8257044,
#           &quot;urban_park&quot;: 2517.0
#         },
#         {
#           &quot;latitude&quot;:
